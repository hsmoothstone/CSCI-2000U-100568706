# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import genfromtxt
# %matplotlib inline

array = genfromtxt('ISSN_D_tot.csv', delimiter=',',  dtype=float)
year = genfromtxt('ISSN_D_tot.csv', delimiter=',',usecols=(0),  dtype=float)
month = genfromtxt('ISSN_D_tot.csv', delimiter=',',usecols=(1),  dtype=float)
day = genfromtxt('ISSN_D_tot.csv', delimiter=',',usecols=(2),  dtype=float)
date = genfromtxt('ISSN_D_tot.csv', delimiter=',',usecols=(3),  dtype=float)
observed = genfromtxt('ISSN_D_tot.csv', delimiter=',',usecols=(4),  dtype=float)
flag = genfromtxt('ISSN_D_tot.csv', delimiter=',',usecols=(5),  dtype=float)

print("the most recent observation was on:   ",date.max())

#calculate mean
mean = observed.mean()
print("the mean of the number of observations is:", mean)

#calculate median
median =observed[-1/2] 
print("the median of number of observations is: " ,median)



plt.plot(date , observed,"c.")

plt.suptitle("daily sunspot observations (1818 to 2014)")


#not sure how to add a line to the plot
#not sure how to save as png

plt.show()
# Out:
# the most recent observation was on:    2015.411
# the mean of the number of observations is: 51.3102601797
# the median of number of observations is:  -1.0
